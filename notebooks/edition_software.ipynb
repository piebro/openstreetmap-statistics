# %% [markdown]
# # Editing Software

# %%
import duckdb
import pandas as pd

default_layout = dict(
    margin=dict(l=55, r=55, b=55, t=55),
    font=dict(family="Times", size=15),
    title_x=0.5,
    paper_bgcolor="#f5f2f0",
    plot_bgcolor="#f5f2f0",
    xaxis=dict(tickcolor="black", linecolor="black", showgrid=True, gridcolor="darkgray", zerolinecolor="darkgray"),
    yaxis=dict(
        tickcolor="black",
        linecolor="black",
        showgrid=True,
        gridcolor="darkgray",
        zerolinecolor="darkgray",
        rangemode="tozero",
    ),
)
pd.set_option("display.max_rows", 100)

# %% [markdown]
# ## Top 10 Editing Software by Yearly Edit Count

# %%
# Section 1, "10 most used editors"
sql_query = """
WITH software_yearly_edits AS (
	SELECT
		year,
		created_by,
		CAST(SUM(edit_count) as BIGINT) as edits
	FROM '../data_enriched/year=*/month=*/*.parquet'
	WHERE created_by IS NOT NULL
	GROUP BY year, created_by
),
software_total_edits AS (
	SELECT
		created_by,
		CAST(SUM(edits) as BIGINT) as total_edits
	FROM software_yearly_edits
	GROUP BY created_by
	ORDER BY total_edits DESC
	LIMIT 10
)
SELECT
	year,
	created_by,
	edits
FROM software_yearly_edits
WHERE created_by IN (SELECT created_by FROM software_total_edits)
ORDER BY year, created_by
"""
df = duckdb.sql(sql_query).df()

pivot_table = (
    df.pivot_table(
        index="created_by",
        columns="year",
        values="edits",
    )
    .fillna(0)
    .astype(int)
)
pivot_table.columns.name = "Editor"
pivot_table.index.name = None
pivot_table["Total"] = pivot_table.sum(axis=1)
pivot_table = pivot_table.sort_values("Total", ascending=False)
pivot_table
# Out:
# Editor               2009       2010       2011       2012       2013  \
# JOSM            125617731  494460089  539135966  542128543  500031429
# iD                      0          0          0          0   34430862
# Potlatch         44030413   64726838  100956564  147706379  133843837
# Rapid                   0          0          0          0          0
# osmtools        150412240    8994328     981921    1229689    2734257
# bulk_upload.py   64669041   24649625    1442184     759090     185033
# StreetComplete          0          0          0          0          0
# Merkaartor        5378663   10887187   10250026    9702870    4380406
# upload.py        31167015   10166002    2402891     421238     776590
# Vespucci             2087      22298      49455     165722     277566
#
# Editor               2014       2015       2016       2017       2018  \
# JOSM            666714750  642725919  625443152  664171922  794010429
# iD              109275830  142202485  189396418  279162048  321342148
# Potlatch         78092007   60204602   42988829   33377795   25182374
# Rapid                   0          0          0          0          0
# osmtools          1499370    6826400   15035558    2655505    3271989
# bulk_upload.py       8089    1061001    1113638       2398       1036
# StreetComplete          0          0         85    1256558    1701133
# Merkaartor        3791724    3696590    2522894    1735350    2138115
# upload.py          422731     488194       4827      38997       3021
# Vespucci           804178     885787    1055056    1559094    2073139
#
# Editor               2019       2020       2021       2022       2023  \
# JOSM            790721973  996077692  917485702  758566474  756759812
# iD              359664267  459865024  480370002  416745824  427963559
# Potlatch         20637960   17371354    5083644    2678828    2574667
# Rapid            11678103   51870526   63919308   63564994   63683830
# osmtools          7558536    6454470    8152531   12399003   29128241
# bulk_upload.py   26933301     263564     464798          0          0
# StreetComplete    1983723    3934118   12439388   12904369   13630403
# Merkaartor        2316287    1745000     334114     491775     123828
# upload.py            4195    1853644    4378760     822536     968637
# Vespucci          2296702    3560018    3517790    3864897    4998545
#
# Editor               2024       2025        Total
# JOSM            767135437  325128093  10906315113
# iD              428165596  191281367   3839865430
# Potlatch          2766754     977964    783200809
# Rapid            52467053   20156724    327340538
# osmtools          2154313     578476    260066827
# bulk_upload.py       4341          0    121557139
# StreetComplete   12782820    4729050     65361647
# Merkaartor          96656     150822     59742307
# upload.py         2536270     699623     57155171
# Vespucci          9855980    5241579     40229893

# %%
# Section 1, "100 most used editors"
sql_query = """
WITH software_yearly_edits AS (
	SELECT
		year,
		created_by,
		CAST(SUM(edit_count) as BIGINT) as edits
	FROM '../data_enriched/year=*/month=*/*.parquet'
	WHERE created_by IS NOT NULL
	GROUP BY year, created_by
),
software_total_edits AS (
	SELECT
		created_by,
		CAST(SUM(edits) as BIGINT) as total_edits
	FROM software_yearly_edits
	GROUP BY created_by
	ORDER BY total_edits DESC
	LIMIT 100
)
SELECT
	year,
	created_by,
	edits
FROM software_yearly_edits
WHERE created_by IN (SELECT created_by FROM software_total_edits)
ORDER BY year, created_by
"""
df = duckdb.sql(sql_query).df()

pivot_table = (
    df.pivot_table(
        index="created_by",
        columns="year",
        values="edits",
    )
    .fillna(0)
    .astype(int)
)
pivot_table.columns.name = "Editor"
pivot_table.index.name = None
pivot_table["Total"] = pivot_table.sum(axis=1)
pivot_table = pivot_table.sort_values("Total", ascending=False)
pivot_table
# Out:
# Editor                                          2009       2010       2011  \
# JOSM                                       125617731  494460089  539135966
# iD                                                 0          0          0
# Potlatch                                    44030413   64726838  100956564
# Rapid                                              0          0          0
# osmtools                                   150412240    8994328     981921
# bulk_upload.py                              64669041   24649625    1442184
# StreetComplete                                     0          0          0
# Merkaartor                                   5378663   10887187   10250026
# upload.py                                   31167015   10166002    2402891
# Vespucci                                        2087      22298      49455
# Go Map!!                                           0          0          0
# osmapi                                             0          0          0
# Redaction bot                                      0          0          0
# osmupload.py                                       0          0          0
# osm-revert                                         0          1          0
# PythonOsmApi                                 2236227     919863    9502991
# bulk_upload_sax.py                           7781579     722332          0
# autoAWS                                            0          0          0
# osmapis                                            0          0          0
# StreetComplete_ee                                  0          0          0
# ArcGIS Editor for OpenStreetMap                    0      15203     418665
# Jeff's Uploader                                    0    5128684          0
# SviMik                                             0          0          0
# FindvejBot                                       262    3797787     358760
# Roy                                                0          0          0
# MAPS.ME                                            0          0          0
# AND node cleaner                             3314543          0          0
# MapComplete                                        0          0          0
# MyUploader                                         0    2660404          0
# Level0                                             0          0          0
# OsmAnd                                             0       4726      11576
# Every Door                                         0          0          0
# osmlinzaddr.py                                     0          0          0
# Zaczero/osm-budynki-orto-import                    0          0          0
# bash script                                        0          0          0
# Osmose Editor                                      0          0          0
# JOpenMapVN/1.5 (19039 SVN en)                      0          0          0
# https://osm.wikidata.link/                         0          0          0
# https_all_the_things                               0          0          0
# rosemary                                           0          0          0
# LINZ Data Import                                   0          0          0
# Globe                                              0          0          0
# LINZ Address Import                                0          0          0
# OSM Translator UA                                  0          0          0
# FixKarlsruheSchema                            122694     271085     426449
# addr2osm                                           0          0          0
# OsmPipeline                                        0          0          0
# OsmInEdit                                          0          0          0
# custom upload script written in ruby          623227          0          0
# OsmHydrant                                         0          0          0
# mat's little ruby script                      591995          0          0
# LangToolsOSM                                       0          0          0
# Organic Maps                                       0          0          0
# Services_OpenStreetMap                             0          0          0
# Mapzen                                         26528     417545      80326
# OsmSharp                                           0          0          0
# OSM Editor UA                                      0          0          0
# Map builder                                        0          0          0
# Osm Go!                                            0          0          0
# Rinux                                         274083      70286          0
# Win Osm Editor                                     0          0          0
# Go Kaart!!                                         0          0          0
# naptan2osm                                    280935       4932          0
# iD-indoor                                          0          0          0
#                                                 5580          0       1819
# FixDoubleNodes                                  7511     174515      76666
# RevertUI                                           0          0          0
# OpenGISData                                        0          0          0
# FixTypo7                                           0          0     207292
# wheelmap.org                                       0      22898     174901
# TrimTags                                       26310     188876      10483
# PHP                                                0          0          0
# PeoriaJanitor                                      0     195442          0
# David Nicholson                                    0          0          0
# MapRoulette                                        0          0          0
# TELCOM IP                                          0         75     180627
# Pic4Review                                         0          0          0
# catatom3dfix                                       0          0          0
# Osmaxil                                            0          0          0
# Pushpin                                            0          0          0
# simple_revert.py                                   0          0          0
# RawEdit                                            0      19050      27561
# Tagger                                             0          0          0
# bulkyosm.py                                        0          0          0
# Zaczero/osm-relatify                               0          0          0
# DataNovaImportScripts                              0          0          0
# Columbia County                                    0          0          0
# MaliMrav-Bot                                       0          0          0
# QGIS OSM                                        4206      30901      29737
# AND retagger                                       0     108633          0
# HI Streams                                         0          0          0
# osm-rnd 0.0.2-dev osm_act_Commit()                 0          0          0
# Gerrit Hendriksen                                  0          0          0
# International Solar Information Solutions          0          0      97578
# Abakus StrazakOSM uploader                         0          0          0
# Findeschorse007                                 4462      81237          1
# https://github.com/Cyrille37/yapafo v2.0           0          0          0
# OsmSeaShark-EffacerWays                            0      79146          0
# ADDR                                               0          0          0
# https://wheelmap.org                               0          0          0
#
# Editor                                          2012       2013       2014  \
# JOSM                                       542128543  500031429  666714750
# iD                                                 0   34430862  109275830
# Potlatch                                   147706379  133843837   78092007
# Rapid                                              0          0          0
# osmtools                                     1229689    2734257    1499370
# bulk_upload.py                                759090     185033       8089
# StreetComplete                                     0          0          0
# Merkaartor                                   9702870    4380406    3791724
# upload.py                                     421238     776590     422731
# Vespucci                                      165722     277566     804178
# Go Map!!                                           0     499238     632666
# osmapi                                             0          0     797190
# Redaction bot                               21303266     284119     102887
# osmupload.py                                       0   18057237          0
# osm-revert                                         0          0          0
# PythonOsmApi                                   44696      29989      25418
# bulk_upload_sax.py                             52554          0      35010
# autoAWS                                            0          0          0
# osmapis                                      4169283     343809     327196
# StreetComplete_ee                                  0          0          0
# ArcGIS Editor for OpenStreetMap                39091     186947    1483853
# Jeff's Uploader                                    0          0          0
# SviMik                                          5569    3060161          0
# FindvejBot                                    104606        175          0
# Roy                                          1216065    2940171          0
# MAPS.ME                                            0          0          0
# AND node cleaner                                   0          0          0
# MapComplete                                        0          0          0
# MyUploader                                         0          0          0
# Level0                                             0          0      25528
# OsmAnd                                         22532      36647      56023
# Every Door                                         0          0          0
# osmlinzaddr.py                                     0          0          0
# Zaczero/osm-budynki-orto-import                    0          0          0
# bash script                                        0          0          0
# Osmose Editor                                      0          0      20371
# JOpenMapVN/1.5 (19039 SVN en)                      0          0          0
# https://osm.wikidata.link/                         0          0          0
# https_all_the_things                               0          0          0
# rosemary                                       59090     107887      89020
# LINZ Data Import                                   0          0          0
# Globe                                              0          0          0
# LINZ Address Import                                0          0          0
# OSM Translator UA                                  0          0          0
# FixKarlsruheSchema                              3941          0          0
# addr2osm                                           0          0          0
# OsmPipeline                                        0          0          0
# OsmInEdit                                          0          0          0
# custom upload script written in ruby               0          0          0
# OsmHydrant                                         0         21      19935
# mat's little ruby script                           0          0          0
# LangToolsOSM                                       0          0          0
# Organic Maps                                       0          0          0
# Services_OpenStreetMap                         28736      18942      99656
# Mapzen                                          4086          0          0
# OsmSharp                                      501526          0         16
# OSM Editor UA                                      0          0          0
# Map builder                                        0          0          0
# Osm Go!                                            0          0          0
# Rinux                                              0          0          0
# Win Osm Editor                                     0          0     326545
# Go Kaart!!                                         0          0          0
# naptan2osm                                         0          0          0
# iD-indoor                                          0          0          0
#                                                    0          0     251292
# FixDoubleNodes                                 11259          0          0
# RevertUI                                           0          0          0
# OpenGISData                                        0     257667          0
# FixTypo7                                       47914          0          0
# wheelmap.org                                   34959          0          0
# TrimTags                                         266          0          0
# PHP                                                0          0          0
# PeoriaJanitor                                      0          0          0
# David Nicholson                                    0          0          0
# MapRoulette                                        0          0          0
# TELCOM IP                                       1021          0         79
# Pic4Review                                         0          0          0
# catatom3dfix                                       0          0          0
# Osmaxil                                            0          0          0
# Pushpin                                         9837      62718      35563
# simple_revert.py                                   0          0          0
# RawEdit                                        28837      31049      14062
# Tagger                                             0          0          0
# bulkyosm.py                                        0          0     141000
# Zaczero/osm-relatify                               0          0          0
# DataNovaImportScripts                              0          0          0
# Columbia County                                    0          0          0
# MaliMrav-Bot                                       0          0          0
# QGIS OSM                                       36097       9488         85
# AND retagger                                       0          0          0
# HI Streams                                         0          0          0
# osm-rnd 0.0.2-dev osm_act_Commit()                 0          0          0
# Gerrit Hendriksen                                  0          0          0
# International Solar Information Solutions          0          0          0
# Abakus StrazakOSM uploader                         0          0          0
# Findeschorse007                                    0          0          0
# https://github.com/Cyrille37/yapafo v2.0           0          0          0
# OsmSeaShark-EffacerWays                            0          0          0
# ADDR                                               0          0          0
# https://wheelmap.org                               0          0          0
#
# Editor                                          2015       2016       2017  \
# JOSM                                       642725919  625443152  664171922
# iD                                         142202485  189396418  279162048
# Potlatch                                    60204602   42988829   33377795
# Rapid                                              0          0          0
# osmtools                                     6826400   15035558    2655505
# bulk_upload.py                               1061001    1113638       2398
# StreetComplete                                     0         85    1256558
# Merkaartor                                   3696590    2522894    1735350
# upload.py                                     488194       4827      38997
# Vespucci                                      885787    1055056    1559094
# Go Map!!                                      976605     891117    1141922
# osmapi                                        139521     682193     288536
# Redaction bot                                  81142     195753     278968
# osmupload.py                                 2109443          0          0
# osm-revert                                         0          0          0
# PythonOsmApi                                   27000       3343       7432
# bulk_upload_sax.py                                 0          0          0
# autoAWS                                            0          0          0
# osmapis                                       137593     307650      95443
# StreetComplete_ee                                  0          0          0
# ArcGIS Editor for OpenStreetMap               146144      86338     440235
# Jeff's Uploader                                    0          0          0
# SviMik                                             0          0          0
# FindvejBot                                         0          0          0
# Roy                                                0          0          0
# MAPS.ME                                            0     812010    1033627
# AND node cleaner                                   0          0          0
# MapComplete                                        0          0          0
# MyUploader                                         0          0          0
# Level0                                        113023     146327     188651
# OsmAnd                                         72002     113364     151873
# Every Door                                         0          0          0
# osmlinzaddr.py                                     0          0     229011
# Zaczero/osm-budynki-orto-import                    0          0          0
# bash script                                        0          0          0
# Osmose Editor                                  50115      67917     124560
# JOpenMapVN/1.5 (19039 SVN en)                      0          0          0
# https://osm.wikidata.link/                         0          0      83997
# https_all_the_things                               0          0          0
# rosemary                                      146213     126016     121314
# LINZ Data Import                                   0          0          0
# Globe                                              0          0          0
# LINZ Address Import                                0          0          0
# OSM Translator UA                                  0          0          0
# FixKarlsruheSchema                                 0        132          0
# addr2osm                                           0          0          0
# OsmPipeline                                        0          0          0
# OsmInEdit                                          0          0          0
# custom upload script written in ruby               0          0          0
# OsmHydrant                                     49350      43986      51439
# mat's little ruby script                           0          0          0
# LangToolsOSM                                       0          0          0
# Organic Maps                                       0          0          0
# Services_OpenStreetMap                        124012      60583      53450
# Mapzen                                             0          0          0
# OsmSharp                                           0          0          0
# OSM Editor UA                                      0          0          0
# Map builder                                        0          0          0
# Osm Go!                                            0        838       1136
# Rinux                                              0          0          0
# Win Osm Editor                                     0          0          0
# Go Kaart!!                                         0          0          0
# naptan2osm                                         0          0          0
# iD-indoor                                          0       4911      41387
#                                                    0          0          1
# FixDoubleNodes                                     0          0          0
# RevertUI                                           0       2431      12626
# OpenGISData                                        0          0          0
# FixTypo7                                           0          0          0
# wheelmap.org                                       0          0          0
# TrimTags                                           0          0          0
# PHP                                                0          0          0
# PeoriaJanitor                                      0          0          0
# David Nicholson                                    0          0          0
# MapRoulette                                        0          0          0
# TELCOM IP                                         18          0          0
# Pic4Review                                         0          0          0
# catatom3dfix                                       0          0          0
# Osmaxil                                        49004          0     118268
# Pushpin                                        27135      15091       6810
# simple_revert.py                                   0       2521       4159
# RawEdit                                         8173      22400       2834
# Tagger                                             0          0     146189
# bulkyosm.py                                        0          0          0
# Zaczero/osm-relatify                               0          0          0
# DataNovaImportScripts                              0          0          0
# Columbia County                                    0          0          0
# MaliMrav-Bot                                       0          0          0
# QGIS OSM                                           0          0          1
# AND retagger                                       0          0          0
# HI Streams                                         0          0          0
# osm-rnd 0.0.2-dev osm_act_Commit()                 0          0          0
# Gerrit Hendriksen                                  0          0          0
# International Solar Information Solutions          0          0          0
# Abakus StrazakOSM uploader                         0          0       8097
# Findeschorse007                                    0          0          0
# https://github.com/Cyrille37/yapafo v2.0           0          0          0
# OsmSeaShark-EffacerWays                            0          0          0
# ADDR                                               0          0          0
# https://wheelmap.org                               0          0          0
#
# Editor                                          2018       2019       2020  \
# JOSM                                       794010429  790721973  996077692
# iD                                         321342148  359664267  459865024
# Potlatch                                    25182374   20637960   17371354
# Rapid                                              0   11678103   51870526
# osmtools                                     3271989    7558536    6454470
# bulk_upload.py                                  1036   26933301     263564
# StreetComplete                               1701133    1983723    3934118
# Merkaartor                                   2138115    2316287    1745000
# upload.py                                       3021       4195    1853644
# Vespucci                                     2073139    2296702    3560018
# Go Map!!                                     2456011    3674118    4916477
# osmapi                                        240521     162631    2095734
# Redaction bot                                 323820     308288    3375623
# osmupload.py                                       0      41463      11841
# osm-revert                                         0          0          0
# PythonOsmApi                                       0          0          0
# bulk_upload_sax.py                                 0          0          0
# autoAWS                                      2674602      76127     178939
# osmapis                                        64731          0          0
# StreetComplete_ee                                  0          0          0
# ArcGIS Editor for OpenStreetMap               762971     340745     841484
# Jeff's Uploader                                    0          0          0
# SviMik                                             0    1692718      15570
# FindvejBot                                         0          0          0
# Roy                                                0          0          0
# MAPS.ME                                       712942     613554     348812
# AND node cleaner                                   0          0          0
# MapComplete                                        0          0       6209
# MyUploader                                         0          0          0
# Level0                                        320786     206785     233316
# OsmAnd                                        204448     251119     245872
# Every Door                                         0          0          0
# osmlinzaddr.py                               1597789        666       4847
# Zaczero/osm-budynki-orto-import                    0          0          0
# bash script                                        0        124       7548
# Osmose Editor                                  70201     152085     232896
# JOpenMapVN/1.5 (19039 SVN en)                      0          0          0
# https://osm.wikidata.link/                     95677     114685     231241
# https_all_the_things                               0     492096      11218
# rosemary                                      105922      68136      31187
# LINZ Data Import                                   0          0          0
# Globe                                              0          0     571857
# LINZ Address Import                                0          0          0
# OSM Translator UA                                  0          0          0
# FixKarlsruheSchema                                 0          0          0
# addr2osm                                      251851     171967     111782
# OsmPipeline                                        0       1566     650184
# OsmInEdit                                          0      33297      51125
# custom upload script written in ruby               0          0          0
# OsmHydrant                                     51988      58993      81622
# mat's little ruby script                           0          0          0
# LangToolsOSM                                       0          0          0
# Organic Maps                                       0          0          0
# Services_OpenStreetMap                          1704      22260     126712
# Mapzen                                             0          0          0
# OsmSharp                                           0          0          0
# OSM Editor UA                                      0          0          0
# Map builder                                        0          0          0
# Osm Go!                                         6203      19973      27519
# Rinux                                              0          0          0
# Win Osm Editor                                     0          0          0
# Go Kaart!!                                     79512     108567      88530
# naptan2osm                                         0          0          0
# iD-indoor                                     158328      50262      11956
#                                                    0          0        173
# FixDoubleNodes                                     0          0          0
# RevertUI                                       27200      16729      39026
# OpenGISData                                        0          0          0
# FixTypo7                                           0          0          0
# wheelmap.org                                       0          0          0
# TrimTags                                           0          0          0
# PHP                                                0          0          0
# PeoriaJanitor                                      0          0          0
# David Nicholson                                    0     190054          0
# MapRoulette                                        0       1517       3449
# TELCOM IP                                          0          0          0
# Pic4Review                                     21168      41649      42694
# catatom3dfix                                       0          0          0
# Osmaxil                                            0          0          0
# Pushpin                                          767          0          0
# simple_revert.py                               22951       8398       4762
# RawEdit                                          876          0          0
# Tagger                                             0          0          0
# bulkyosm.py                                        0          0          0
# Zaczero/osm-relatify                               0          0          0
# DataNovaImportScripts                              0          0      25162
# Columbia County                                    0          0          0
# MaliMrav-Bot                                       0          0          0
# QGIS OSM                                           0          0          0
# AND retagger                                       0          0          0
# HI Streams                                         0          0          0
# osm-rnd 0.0.2-dev osm_act_Commit()                 0          0          0
# Gerrit Hendriksen                                  0          0          0
# International Solar Information Solutions          0          0          0
# Abakus StrazakOSM uploader                     30091      15590      13253
# Findeschorse007                                    0          0          0
# https://github.com/Cyrille37/yapafo v2.0           0          0          0
# OsmSeaShark-EffacerWays                            0          0          0
# ADDR                                               0      77473          0
# https://wheelmap.org                               0          0          0
#
# Editor                                          2021       2022       2023  \
# JOSM                                       917485702  758566474  756759812
# iD                                         480370002  416745824  427963559
# Potlatch                                     5083644    2678828    2574667
# Rapid                                       63919308   63564994   63683830
# osmtools                                     8152531   12399003   29128241
# bulk_upload.py                                464798          0          0
# StreetComplete                              12439388   12904369   13630403
# Merkaartor                                    334114     491775     123828
# upload.py                                    4378760     822536     968637
# Vespucci                                     3517790    3864897    4998545
# Go Map!!                                     4733594    4394577    4263021
# osmapi                                      23940911    1860602    1030376
# Redaction bot                                  33835       8164     521134
# osmupload.py                                       0          0        521
# osm-revert                                         0          0   14476276
# PythonOsmApi                                       0          0          0
# bulk_upload_sax.py                                 0          0          0
# autoAWS                                       133574    2635334      87343
# osmapis                                            0          0          0
# StreetComplete_ee                                  0      83493    1174799
# ArcGIS Editor for OpenStreetMap               216823      80789      61768
# Jeff's Uploader                                    0          0          0
# SviMik                                          3609          0          0
# FindvejBot                                         0          0          0
# Roy                                                0          0          0
# MAPS.ME                                       201795      96002     115484
# AND node cleaner                                   0          0          0
# MapComplete                                    52676     949795     860297
# MyUploader                                         0          0          0
# Level0                                        237719     373908     294926
# OsmAnd                                        263291     320702     252725
# Every Door                                         0     299698     707179
# osmlinzaddr.py                                     0          0          0
# Zaczero/osm-budynki-orto-import                    0          0    1062702
# bash script                                  1237987          1          0
# Osmose Editor                                 124253     127328     106488
# JOpenMapVN/1.5 (19039 SVN en)                      0          0          0
# https://osm.wikidata.link/                    105159      61907     126637
# https_all_the_things                           10430      62062     365444
# rosemary                                       70926      38168      31655
# LINZ Data Import                               80773     178965     288331
# Globe                                         332213          0          0
# LINZ Address Import                           859965          0         57
# OSM Translator UA                                  0          0     857795
# FixKarlsruheSchema                                 0          0          0
# addr2osm                                       88066      90153      21318
# OsmPipeline                                        0          0          0
# OsmInEdit                                     146744      90737     162561
# custom upload script written in ruby               0          0          0
# OsmHydrant                                     65983      64653      59224
# mat's little ruby script                           0          0          0
# LangToolsOSM                                   22136     489441      59878
# Organic Maps                                   32911     115220     143570
# Services_OpenStreetMap                           509       2074         76
# Mapzen                                             0          0          0
# OsmSharp                                           0          0          0
# OSM Editor UA                                      0          0     415557
# Map builder                                     3768      69618     100285
# Osm Go!                                        44713     186849      50670
# Rinux                                              0          0          0
# Win Osm Editor                                     0          0          0
# Go Kaart!!                                     24764      10539       7023
# naptan2osm                                         0          0          0
# iD-indoor                                       1320       3541      10332
#                                                    0          0       5220
# FixDoubleNodes                                     0          0          0
# RevertUI                                       29551      59342      55146
# OpenGISData                                        0          0          0
# FixTypo7                                           0          0          0
# wheelmap.org                                       0          0          0
# TrimTags                                           0          0          0
# PHP                                                0     218337          0
# PeoriaJanitor                                      0          0          0
# David Nicholson                                    0          0          0
# MapRoulette                                    21339      60679      65758
# TELCOM IP                                          0          0          0
# Pic4Review                                     28055      22014      10172
# catatom3dfix                                  176205          0          0
# Osmaxil                                            0          0          0
# Pushpin                                            0          0          0
# simple_revert.py                               12395      88217       2373
# RawEdit                                            0          0          0
# Tagger                                             0          0          0
# bulkyosm.py                                        0          0          0
# Zaczero/osm-relatify                               0          0      29362
# DataNovaImportScripts                          52074       6790      28146
# Columbia County                               126632          0          0
# MaliMrav-Bot                                       0          0          0
# QGIS OSM                                           0          0          0
# AND retagger                                       0          0          0
# HI Streams                                         0     106530          0
# osm-rnd 0.0.2-dev osm_act_Commit()                 0          0          0
# Gerrit Hendriksen                              98300          0          0
# International Solar Information Solutions          0          0          0
# Abakus StrazakOSM uploader                      8941       7290       5417
# Findeschorse007                                    0          0          0
# https://github.com/Cyrille37/yapafo v2.0           0          0          0
# OsmSeaShark-EffacerWays                            0          0          0
# ADDR                                               0          0          0
# https://wheelmap.org                               0          0       9673
#
# Editor                                          2024       2025        Total
# JOSM                                       767135437  325128093  10906315113
# iD                                         428165596  191281367   3839865430
# Potlatch                                     2766754     977964    783200809
# Rapid                                       52467053   20156724    327340538
# osmtools                                     2154313     578476    260066827
# bulk_upload.py                                  4341          0    121557139
# StreetComplete                              12782820    4729050     65361647
# Merkaartor                                     96656     150822     59742307
# upload.py                                    2536270     699623     57155171
# Vespucci                                     9855980    5241579     40229893
# Go Map!!                                     4439158    2191499     35210003
# osmapi                                       1094794     228761     32561770
# Redaction bot                                   1471          0     26818470
# osmupload.py                                       0          0     20220505
# osm-revert                                   2208477    1192586     17877340
# PythonOsmApi                                       0          0     12796959
# bulk_upload_sax.py                                 0          0      8591475
# autoAWS                                        66735      22059      5874713
# osmapis                                            0          0      5445705
# StreetComplete_ee                            2695077    1389807      5343176
# ArcGIS Editor for OpenStreetMap                33541          0      5154597
# Jeff's Uploader                                    0          0      5128684
# SviMik                                             0          0      4777627
# FindvejBot                                         0          0      4261590
# Roy                                                0          0      4156236
# MAPS.ME                                        42820      11333      3988379
# AND node cleaner                                   0          0      3314543
# MapComplete                                  1054430     251290      3174697
# MyUploader                                         0          0      2660404
# Level0                                        336536     153325      2630830
# OsmAnd                                        210077      79071      2296048
# Every Door                                    877360     370051      2254288
# osmlinzaddr.py                                     0          0      1832313
# Zaczero/osm-budynki-orto-import               215078          0      1277780
# bash script                                       80          0      1245740
# Osmose Editor                                  50261      14608      1141083
# JOpenMapVN/1.5 (19039 SVN en)                1104218          0      1104218
# https://osm.wikidata.link/                    171325      53403      1044031
# https_all_the_things                           76678      12049      1029977
# rosemary                                           0          0       995534
# LINZ Data Import                              277839     164273       990181
# Globe                                              0          0       904070
# LINZ Address Import                                0          0       860022
# OSM Translator UA                                  0          0       857795
# FixKarlsruheSchema                                 0          0       824301
# addr2osm                                           0          0       735137
# OsmPipeline                                        0          0       651750
# OsmInEdit                                     106842      47741       639047
# custom upload script written in ruby               0          0       623227
# OsmHydrant                                     42327      16919       606440
# mat's little ruby script                           0          0       591995
# LangToolsOSM                                       0          0       571455
# Organic Maps                                  178015      83944       553660
# Services_OpenStreetMap                            41          0       538755
# Mapzen                                             0          0       528485
# OsmSharp                                           0          0       501542
# OSM Editor UA                                      0          0       415557
# Map builder                                   235241          0       408912
# Osm Go!                                        35478      13652       387031
# Rinux                                              0          0       344369
# Win Osm Editor                                     0          0       326545
# Go Kaart!!                                      4271          0       323206
# naptan2osm                                         0          0       285867
# iD-indoor                                        312          0       282349
#                                                 6757          0       270842
# FixDoubleNodes                                     0          0       269951
# RevertUI                                       17218       7932       267201
# OpenGISData                                        0          0       257667
# FixTypo7                                           0          0       255206
# wheelmap.org                                       0          0       232758
# TrimTags                                           0          0       225935
# PHP                                                0          0       218337
# PeoriaJanitor                                      0          0       195442
# David Nicholson                                    0          0       190054
# MapRoulette                                    22649      10632       186023
# TELCOM IP                                          0          0       181820
# Pic4Review                                      9415       1674       176841
# catatom3dfix                                       0          0       176205
# Osmaxil                                            0          0       167272
# Pushpin                                            0          0       157921
# simple_revert.py                                9508       1276       156560
# RawEdit                                            0          0       154842
# Tagger                                             0          0       146189
# bulkyosm.py                                        0          0       141000
# Zaczero/osm-relatify                           72944      30644       132950
# DataNovaImportScripts                          17389          0       129561
# Columbia County                                    0          0       126632
# MaliMrav-Bot                                  108313       7830       116143
# QGIS OSM                                           0          0       110515
# AND retagger                                       0          0       108633
# HI Streams                                         0          0       106530
# osm-rnd 0.0.2-dev osm_act_Commit()            100961          0       100961
# Gerrit Hendriksen                                  0          0        98300
# International Solar Information Solutions          0          0        97578
# Abakus StrazakOSM uploader                      3591       2194        94464
# Findeschorse007                                    0          0        85700
# https://github.com/Cyrille37/yapafo v2.0       81915          0        81915
# OsmSeaShark-EffacerWays                            0          0        79146
# ADDR                                               0          0        77473
# https://wheelmap.org                           42663      24823        77159

# %% [markdown]
# ## More

# %%
sql_query = """
WITH software_yearly_edits AS (
	SELECT
		year,
		created_by,
		CAST(SUM(edit_count) as BIGINT) as edits
	FROM '../data_enriched/year=*/month=*/*.parquet'
	WHERE created_by IS NOT NULL
	GROUP BY year, created_by
),
software_total_edits AS (
	SELECT
		created_by,
		CAST(SUM(edits) as BIGINT) as total_edits
	FROM software_yearly_edits
	GROUP BY created_by
	ORDER BY total_edits DESC
	LIMIT 100
)
SELECT
	year,
	created_by,
	edits
FROM software_yearly_edits
WHERE created_by IN (SELECT created_by FROM software_total_edits)
ORDER BY year, created_by
"""
df = duckdb.sql(sql_query).df()

pivot_table = (
    df.pivot_table(
        index="created_by",
        columns="year",
        values="edits",
    )
    .fillna(0)
    .astype(int)
)
pivot_table.columns.name = "Editor"
pivot_table.index.name = None
pivot_table["Total"] = pivot_table.sum(axis=1)
pivot_table = pivot_table.sort_values("Total", ascending=False)
pivot_table
# Out:
# Editor                                          2009       2010       2011  \
# JOSM                                       125617731  494460089  539135966
# iD                                                 0          0          0
# Potlatch                                    44030413   64726838  100956564
# Rapid                                              0          0          0
# osmtools                                   150412240    8994328     981921
# bulk_upload.py                              64669041   24649625    1442184
# StreetComplete                                     0          0          0
# Merkaartor                                   5378663   10887187   10250026
# upload.py                                   31167015   10166002    2402891
# Vespucci                                        2087      22298      49455
# Go Map!!                                           0          0          0
# osmapi                                             0          0          0
# Redaction bot                                      0          0          0
# osmupload.py                                       0          0          0
# osm-revert                                         0          1          0
# PythonOsmApi                                 2236227     919863    9502991
# bulk_upload_sax.py                           7781579     722332          0
# autoAWS                                            0          0          0
# osmapis                                            0          0          0
# StreetComplete_ee                                  0          0          0
# ArcGIS Editor for OpenStreetMap                    0      15203     418665
# Jeff's Uploader                                    0    5128684          0
# SviMik                                             0          0          0
# FindvejBot                                       262    3797787     358760
# Roy                                                0          0          0
# MAPS.ME                                            0          0          0
# AND node cleaner                             3314543          0          0
# MapComplete                                        0          0          0
# MyUploader                                         0    2660404          0
# Level0                                             0          0          0
# OsmAnd                                             0       4726      11576
# Every Door                                         0          0          0
# osmlinzaddr.py                                     0          0          0
# Zaczero/osm-budynki-orto-import                    0          0          0
# bash script                                        0          0          0
# Osmose Editor                                      0          0          0
# JOpenMapVN/1.5 (19039 SVN en)                      0          0          0
# https://osm.wikidata.link/                         0          0          0
# https_all_the_things                               0          0          0
# rosemary                                           0          0          0
# LINZ Data Import                                   0          0          0
# Globe                                              0          0          0
# LINZ Address Import                                0          0          0
# OSM Translator UA                                  0          0          0
# FixKarlsruheSchema                            122694     271085     426449
# addr2osm                                           0          0          0
# OsmPipeline                                        0          0          0
# OsmInEdit                                          0          0          0
# custom upload script written in ruby          623227          0          0
# OsmHydrant                                         0          0          0
# mat's little ruby script                      591995          0          0
# LangToolsOSM                                       0          0          0
# Organic Maps                                       0          0          0
# Services_OpenStreetMap                             0          0          0
# Mapzen                                         26528     417545      80326
# OsmSharp                                           0          0          0
# OSM Editor UA                                      0          0          0
# Map builder                                        0          0          0
# Osm Go!                                            0          0          0
# Rinux                                         274083      70286          0
# Win Osm Editor                                     0          0          0
# Go Kaart!!                                         0          0          0
# naptan2osm                                    280935       4932          0
# iD-indoor                                          0          0          0
#                                                 5580          0       1819
# FixDoubleNodes                                  7511     174515      76666
# RevertUI                                           0          0          0
# OpenGISData                                        0          0          0
# FixTypo7                                           0          0     207292
# wheelmap.org                                       0      22898     174901
# TrimTags                                       26310     188876      10483
# PHP                                                0          0          0
# PeoriaJanitor                                      0     195442          0
# David Nicholson                                    0          0          0
# MapRoulette                                        0          0          0
# TELCOM IP                                          0         75     180627
# Pic4Review                                         0          0          0
# catatom3dfix                                       0          0          0
# Osmaxil                                            0          0          0
# Pushpin                                            0          0          0
# simple_revert.py                                   0          0          0
# RawEdit                                            0      19050      27561
# Tagger                                             0          0          0
# bulkyosm.py                                        0          0          0
# Zaczero/osm-relatify                               0          0          0
# DataNovaImportScripts                              0          0          0
# Columbia County                                    0          0          0
# MaliMrav-Bot                                       0          0          0
# QGIS OSM                                        4206      30901      29737
# AND retagger                                       0     108633          0
# HI Streams                                         0          0          0
# osm-rnd 0.0.2-dev osm_act_Commit()                 0          0          0
# Gerrit Hendriksen                                  0          0          0
# International Solar Information Solutions          0          0      97578
# Abakus StrazakOSM uploader                         0          0          0
# Findeschorse007                                 4462      81237          1
# https://github.com/Cyrille37/yapafo v2.0           0          0          0
# OsmSeaShark-EffacerWays                            0      79146          0
# ADDR                                               0          0          0
# https://wheelmap.org                               0          0          0
#
# Editor                                          2012       2013       2014  \
# JOSM                                       542128543  500031429  666714750
# iD                                                 0   34430862  109275830
# Potlatch                                   147706379  133843837   78092007
# Rapid                                              0          0          0
# osmtools                                     1229689    2734257    1499370
# bulk_upload.py                                759090     185033       8089
# StreetComplete                                     0          0          0
# Merkaartor                                   9702870    4380406    3791724
# upload.py                                     421238     776590     422731
# Vespucci                                      165722     277566     804178
# Go Map!!                                           0     499238     632666
# osmapi                                             0          0     797190
# Redaction bot                               21303266     284119     102887
# osmupload.py                                       0   18057237          0
# osm-revert                                         0          0          0
# PythonOsmApi                                   44696      29989      25418
# bulk_upload_sax.py                             52554          0      35010
# autoAWS                                            0          0          0
# osmapis                                      4169283     343809     327196
# StreetComplete_ee                                  0          0          0
# ArcGIS Editor for OpenStreetMap                39091     186947    1483853
# Jeff's Uploader                                    0          0          0
# SviMik                                          5569    3060161          0
# FindvejBot                                    104606        175          0
# Roy                                          1216065    2940171          0
# MAPS.ME                                            0          0          0
# AND node cleaner                                   0          0          0
# MapComplete                                        0          0          0
# MyUploader                                         0          0          0
# Level0                                             0          0      25528
# OsmAnd                                         22532      36647      56023
# Every Door                                         0          0          0
# osmlinzaddr.py                                     0          0          0
# Zaczero/osm-budynki-orto-import                    0          0          0
# bash script                                        0          0          0
# Osmose Editor                                      0          0      20371
# JOpenMapVN/1.5 (19039 SVN en)                      0          0          0
# https://osm.wikidata.link/                         0          0          0
# https_all_the_things                               0          0          0
# rosemary                                       59090     107887      89020
# LINZ Data Import                                   0          0          0
# Globe                                              0          0          0
# LINZ Address Import                                0          0          0
# OSM Translator UA                                  0          0          0
# FixKarlsruheSchema                              3941          0          0
# addr2osm                                           0          0          0
# OsmPipeline                                        0          0          0
# OsmInEdit                                          0          0          0
# custom upload script written in ruby               0          0          0
# OsmHydrant                                         0         21      19935
# mat's little ruby script                           0          0          0
# LangToolsOSM                                       0          0          0
# Organic Maps                                       0          0          0
# Services_OpenStreetMap                         28736      18942      99656
# Mapzen                                          4086          0          0
# OsmSharp                                      501526          0         16
# OSM Editor UA                                      0          0          0
# Map builder                                        0          0          0
# Osm Go!                                            0          0          0
# Rinux                                              0          0          0
# Win Osm Editor                                     0          0     326545
# Go Kaart!!                                         0          0          0
# naptan2osm                                         0          0          0
# iD-indoor                                          0          0          0
#                                                    0          0     251292
# FixDoubleNodes                                 11259          0          0
# RevertUI                                           0          0          0
# OpenGISData                                        0     257667          0
# FixTypo7                                       47914          0          0
# wheelmap.org                                   34959          0          0
# TrimTags                                         266          0          0
# PHP                                                0          0          0
# PeoriaJanitor                                      0          0          0
# David Nicholson                                    0          0          0
# MapRoulette                                        0          0          0
# TELCOM IP                                       1021          0         79
# Pic4Review                                         0          0          0
# catatom3dfix                                       0          0          0
# Osmaxil                                            0          0          0
# Pushpin                                         9837      62718      35563
# simple_revert.py                                   0          0          0
# RawEdit                                        28837      31049      14062
# Tagger                                             0          0          0
# bulkyosm.py                                        0          0     141000
# Zaczero/osm-relatify                               0          0          0
# DataNovaImportScripts                              0          0          0
# Columbia County                                    0          0          0
# MaliMrav-Bot                                       0          0          0
# QGIS OSM                                       36097       9488         85
# AND retagger                                       0          0          0
# HI Streams                                         0          0          0
# osm-rnd 0.0.2-dev osm_act_Commit()                 0          0          0
# Gerrit Hendriksen                                  0          0          0
# International Solar Information Solutions          0          0          0
# Abakus StrazakOSM uploader                         0          0          0
# Findeschorse007                                    0          0          0
# https://github.com/Cyrille37/yapafo v2.0           0          0          0
# OsmSeaShark-EffacerWays                            0          0          0
# ADDR                                               0          0          0
# https://wheelmap.org                               0          0          0
#
# Editor                                          2015       2016       2017  \
# JOSM                                       642725919  625443152  664171922
# iD                                         142202485  189396418  279162048
# Potlatch                                    60204602   42988829   33377795
# Rapid                                              0          0          0
# osmtools                                     6826400   15035558    2655505
# bulk_upload.py                               1061001    1113638       2398
# StreetComplete                                     0         85    1256558
# Merkaartor                                   3696590    2522894    1735350
# upload.py                                     488194       4827      38997
# Vespucci                                      885787    1055056    1559094
# Go Map!!                                      976605     891117    1141922
# osmapi                                        139521     682193     288536
# Redaction bot                                  81142     195753     278968
# osmupload.py                                 2109443          0          0
# osm-revert                                         0          0          0
# PythonOsmApi                                   27000       3343       7432
# bulk_upload_sax.py                                 0          0          0
# autoAWS                                            0          0          0
# osmapis                                       137593     307650      95443
# StreetComplete_ee                                  0          0          0
# ArcGIS Editor for OpenStreetMap               146144      86338     440235
# Jeff's Uploader                                    0          0          0
# SviMik                                             0          0          0
# FindvejBot                                         0          0          0
# Roy                                                0          0          0
# MAPS.ME                                            0     812010    1033627
# AND node cleaner                                   0          0          0
# MapComplete                                        0          0          0
# MyUploader                                         0          0          0
# Level0                                        113023     146327     188651
# OsmAnd                                         72002     113364     151873
# Every Door                                         0          0          0
# osmlinzaddr.py                                     0          0     229011
# Zaczero/osm-budynki-orto-import                    0          0          0
# bash script                                        0          0          0
# Osmose Editor                                  50115      67917     124560
# JOpenMapVN/1.5 (19039 SVN en)                      0          0          0
# https://osm.wikidata.link/                         0          0      83997
# https_all_the_things                               0          0          0
# rosemary                                      146213     126016     121314
# LINZ Data Import                                   0          0          0
# Globe                                              0          0          0
# LINZ Address Import                                0          0          0
# OSM Translator UA                                  0          0          0
# FixKarlsruheSchema                                 0        132          0
# addr2osm                                           0          0          0
# OsmPipeline                                        0          0          0
# OsmInEdit                                          0          0          0
# custom upload script written in ruby               0          0          0
# OsmHydrant                                     49350      43986      51439
# mat's little ruby script                           0          0          0
# LangToolsOSM                                       0          0          0
# Organic Maps                                       0          0          0
# Services_OpenStreetMap                        124012      60583      53450
# Mapzen                                             0          0          0
# OsmSharp                                           0          0          0
# OSM Editor UA                                      0          0          0
# Map builder                                        0          0          0
# Osm Go!                                            0        838       1136
# Rinux                                              0          0          0
# Win Osm Editor                                     0          0          0
# Go Kaart!!                                         0          0          0
# naptan2osm                                         0          0          0
# iD-indoor                                          0       4911      41387
#                                                    0          0          1
# FixDoubleNodes                                     0          0          0
# RevertUI                                           0       2431      12626
# OpenGISData                                        0          0          0
# FixTypo7                                           0          0          0
# wheelmap.org                                       0          0          0
# TrimTags                                           0          0          0
# PHP                                                0          0          0
# PeoriaJanitor                                      0          0          0
# David Nicholson                                    0          0          0
# MapRoulette                                        0          0          0
# TELCOM IP                                         18          0          0
# Pic4Review                                         0          0          0
# catatom3dfix                                       0          0          0
# Osmaxil                                        49004          0     118268
# Pushpin                                        27135      15091       6810
# simple_revert.py                                   0       2521       4159
# RawEdit                                         8173      22400       2834
# Tagger                                             0          0     146189
# bulkyosm.py                                        0          0          0
# Zaczero/osm-relatify                               0          0          0
# DataNovaImportScripts                              0          0          0
# Columbia County                                    0          0          0
# MaliMrav-Bot                                       0          0          0
# QGIS OSM                                           0          0          1
# AND retagger                                       0          0          0
# HI Streams                                         0          0          0
# osm-rnd 0.0.2-dev osm_act_Commit()                 0          0          0
# Gerrit Hendriksen                                  0          0          0
# International Solar Information Solutions          0          0          0
# Abakus StrazakOSM uploader                         0          0       8097
# Findeschorse007                                    0          0          0
# https://github.com/Cyrille37/yapafo v2.0           0          0          0
# OsmSeaShark-EffacerWays                            0          0          0
# ADDR                                               0          0          0
# https://wheelmap.org                               0          0          0
#
# Editor                                          2018       2019       2020  \
# JOSM                                       794010429  790721973  996077692
# iD                                         321342148  359664267  459865024
# Potlatch                                    25182374   20637960   17371354
# Rapid                                              0   11678103   51870526
# osmtools                                     3271989    7558536    6454470
# bulk_upload.py                                  1036   26933301     263564
# StreetComplete                               1701133    1983723    3934118
# Merkaartor                                   2138115    2316287    1745000
# upload.py                                       3021       4195    1853644
# Vespucci                                     2073139    2296702    3560018
# Go Map!!                                     2456011    3674118    4916477
# osmapi                                        240521     162631    2095734
# Redaction bot                                 323820     308288    3375623
# osmupload.py                                       0      41463      11841
# osm-revert                                         0          0          0
# PythonOsmApi                                       0          0          0
# bulk_upload_sax.py                                 0          0          0
# autoAWS                                      2674602      76127     178939
# osmapis                                        64731          0          0
# StreetComplete_ee                                  0          0          0
# ArcGIS Editor for OpenStreetMap               762971     340745     841484
# Jeff's Uploader                                    0          0          0
# SviMik                                             0    1692718      15570
# FindvejBot                                         0          0          0
# Roy                                                0          0          0
# MAPS.ME                                       712942     613554     348812
# AND node cleaner                                   0          0          0
# MapComplete                                        0          0       6209
# MyUploader                                         0          0          0
# Level0                                        320786     206785     233316
# OsmAnd                                        204448     251119     245872
# Every Door                                         0          0          0
# osmlinzaddr.py                               1597789        666       4847
# Zaczero/osm-budynki-orto-import                    0          0          0
# bash script                                        0        124       7548
# Osmose Editor                                  70201     152085     232896
# JOpenMapVN/1.5 (19039 SVN en)                      0          0          0
# https://osm.wikidata.link/                     95677     114685     231241
# https_all_the_things                               0     492096      11218
# rosemary                                      105922      68136      31187
# LINZ Data Import                                   0          0          0
# Globe                                              0          0     571857
# LINZ Address Import                                0          0          0
# OSM Translator UA                                  0          0          0
# FixKarlsruheSchema                                 0          0          0
# addr2osm                                      251851     171967     111782
# OsmPipeline                                        0       1566     650184
# OsmInEdit                                          0      33297      51125
# custom upload script written in ruby               0          0          0
# OsmHydrant                                     51988      58993      81622
# mat's little ruby script                           0          0          0
# LangToolsOSM                                       0          0          0
# Organic Maps                                       0          0          0
# Services_OpenStreetMap                          1704      22260     126712
# Mapzen                                             0          0          0
# OsmSharp                                           0          0          0
# OSM Editor UA                                      0          0          0
# Map builder                                        0          0          0
# Osm Go!                                         6203      19973      27519
# Rinux                                              0          0          0
# Win Osm Editor                                     0          0          0
# Go Kaart!!                                     79512     108567      88530
# naptan2osm                                         0          0          0
# iD-indoor                                     158328      50262      11956
#                                                    0          0        173
# FixDoubleNodes                                     0          0          0
# RevertUI                                       27200      16729      39026
# OpenGISData                                        0          0          0
# FixTypo7                                           0          0          0
# wheelmap.org                                       0          0          0
# TrimTags                                           0          0          0
# PHP                                                0          0          0
# PeoriaJanitor                                      0          0          0
# David Nicholson                                    0     190054          0
# MapRoulette                                        0       1517       3449
# TELCOM IP                                          0          0          0
# Pic4Review                                     21168      41649      42694
# catatom3dfix                                       0          0          0
# Osmaxil                                            0          0          0
# Pushpin                                          767          0          0
# simple_revert.py                               22951       8398       4762
# RawEdit                                          876          0          0
# Tagger                                             0          0          0
# bulkyosm.py                                        0          0          0
# Zaczero/osm-relatify                               0          0          0
# DataNovaImportScripts                              0          0      25162
# Columbia County                                    0          0          0
# MaliMrav-Bot                                       0          0          0
# QGIS OSM                                           0          0          0
# AND retagger                                       0          0          0
# HI Streams                                         0          0          0
# osm-rnd 0.0.2-dev osm_act_Commit()                 0          0          0
# Gerrit Hendriksen                                  0          0          0
# International Solar Information Solutions          0          0          0
# Abakus StrazakOSM uploader                     30091      15590      13253
# Findeschorse007                                    0          0          0
# https://github.com/Cyrille37/yapafo v2.0           0          0          0
# OsmSeaShark-EffacerWays                            0          0          0
# ADDR                                               0      77473          0
# https://wheelmap.org                               0          0          0
#
# Editor                                          2021       2022       2023  \
# JOSM                                       917485702  758566474  756759812
# iD                                         480370002  416745824  427963559
# Potlatch                                     5083644    2678828    2574667
# Rapid                                       63919308   63564994   63683830
# osmtools                                     8152531   12399003   29128241
# bulk_upload.py                                464798          0          0
# StreetComplete                              12439388   12904369   13630403
# Merkaartor                                    334114     491775     123828
# upload.py                                    4378760     822536     968637
# Vespucci                                     3517790    3864897    4998545
# Go Map!!                                     4733594    4394577    4263021
# osmapi                                      23940911    1860602    1030376
# Redaction bot                                  33835       8164     521134
# osmupload.py                                       0          0        521
# osm-revert                                         0          0   14476276
# PythonOsmApi                                       0          0          0
# bulk_upload_sax.py                                 0          0          0
# autoAWS                                       133574    2635334      87343
# osmapis                                            0          0          0
# StreetComplete_ee                                  0      83493    1174799
# ArcGIS Editor for OpenStreetMap               216823      80789      61768
# Jeff's Uploader                                    0          0          0
# SviMik                                          3609          0          0
# FindvejBot                                         0          0          0
# Roy                                                0          0          0
# MAPS.ME                                       201795      96002     115484
# AND node cleaner                                   0          0          0
# MapComplete                                    52676     949795     860297
# MyUploader                                         0          0          0
# Level0                                        237719     373908     294926
# OsmAnd                                        263291     320702     252725
# Every Door                                         0     299698     707179
# osmlinzaddr.py                                     0          0          0
# Zaczero/osm-budynki-orto-import                    0          0    1062702
# bash script                                  1237987          1          0
# Osmose Editor                                 124253     127328     106488
# JOpenMapVN/1.5 (19039 SVN en)                      0          0          0
# https://osm.wikidata.link/                    105159      61907     126637
# https_all_the_things                           10430      62062     365444
# rosemary                                       70926      38168      31655
# LINZ Data Import                               80773     178965     288331
# Globe                                         332213          0          0
# LINZ Address Import                           859965          0         57
# OSM Translator UA                                  0          0     857795
# FixKarlsruheSchema                                 0          0          0
# addr2osm                                       88066      90153      21318
# OsmPipeline                                        0          0          0
# OsmInEdit                                     146744      90737     162561
# custom upload script written in ruby               0          0          0
# OsmHydrant                                     65983      64653      59224
# mat's little ruby script                           0          0          0
# LangToolsOSM                                   22136     489441      59878
# Organic Maps                                   32911     115220     143570
# Services_OpenStreetMap                           509       2074         76
# Mapzen                                             0          0          0
# OsmSharp                                           0          0          0
# OSM Editor UA                                      0          0     415557
# Map builder                                     3768      69618     100285
# Osm Go!                                        44713     186849      50670
# Rinux                                              0          0          0
# Win Osm Editor                                     0          0          0
# Go Kaart!!                                     24764      10539       7023
# naptan2osm                                         0          0          0
# iD-indoor                                       1320       3541      10332
#                                                    0          0       5220
# FixDoubleNodes                                     0          0          0
# RevertUI                                       29551      59342      55146
# OpenGISData                                        0          0          0
# FixTypo7                                           0          0          0
# wheelmap.org                                       0          0          0
# TrimTags                                           0          0          0
# PHP                                                0     218337          0
# PeoriaJanitor                                      0          0          0
# David Nicholson                                    0          0          0
# MapRoulette                                    21339      60679      65758
# TELCOM IP                                          0          0          0
# Pic4Review                                     28055      22014      10172
# catatom3dfix                                  176205          0          0
# Osmaxil                                            0          0          0
# Pushpin                                            0          0          0
# simple_revert.py                               12395      88217       2373
# RawEdit                                            0          0          0
# Tagger                                             0          0          0
# bulkyosm.py                                        0          0          0
# Zaczero/osm-relatify                               0          0      29362
# DataNovaImportScripts                          52074       6790      28146
# Columbia County                               126632          0          0
# MaliMrav-Bot                                       0          0          0
# QGIS OSM                                           0          0          0
# AND retagger                                       0          0          0
# HI Streams                                         0     106530          0
# osm-rnd 0.0.2-dev osm_act_Commit()                 0          0          0
# Gerrit Hendriksen                              98300          0          0
# International Solar Information Solutions          0          0          0
# Abakus StrazakOSM uploader                      8941       7290       5417
# Findeschorse007                                    0          0          0
# https://github.com/Cyrille37/yapafo v2.0           0          0          0
# OsmSeaShark-EffacerWays                            0          0          0
# ADDR                                               0          0          0
# https://wheelmap.org                               0          0       9673
#
# Editor                                          2024       2025        Total
# JOSM                                       767135437  325128093  10906315113
# iD                                         428165596  191281367   3839865430
# Potlatch                                     2766754     977964    783200809
# Rapid                                       52467053   20156724    327340538
# osmtools                                     2154313     578476    260066827
# bulk_upload.py                                  4341          0    121557139
# StreetComplete                              12782820    4729050     65361647
# Merkaartor                                     96656     150822     59742307
# upload.py                                    2536270     699623     57155171
# Vespucci                                     9855980    5241579     40229893
# Go Map!!                                     4439158    2191499     35210003
# osmapi                                       1094794     228761     32561770
# Redaction bot                                   1471          0     26818470
# osmupload.py                                       0          0     20220505
# osm-revert                                   2208477    1192586     17877340
# PythonOsmApi                                       0          0     12796959
# bulk_upload_sax.py                                 0          0      8591475
# autoAWS                                        66735      22059      5874713
# osmapis                                            0          0      5445705
# StreetComplete_ee                            2695077    1389807      5343176
# ArcGIS Editor for OpenStreetMap                33541          0      5154597
# Jeff's Uploader                                    0          0      5128684
# SviMik                                             0          0      4777627
# FindvejBot                                         0          0      4261590
# Roy                                                0          0      4156236
# MAPS.ME                                        42820      11333      3988379
# AND node cleaner                                   0          0      3314543
# MapComplete                                  1054430     251290      3174697
# MyUploader                                         0          0      2660404
# Level0                                        336536     153325      2630830
# OsmAnd                                        210077      79071      2296048
# Every Door                                    877360     370051      2254288
# osmlinzaddr.py                                     0          0      1832313
# Zaczero/osm-budynki-orto-import               215078          0      1277780
# bash script                                       80          0      1245740
# Osmose Editor                                  50261      14608      1141083
# JOpenMapVN/1.5 (19039 SVN en)                1104218          0      1104218
# https://osm.wikidata.link/                    171325      53403      1044031
# https_all_the_things                           76678      12049      1029977
# rosemary                                           0          0       995534
# LINZ Data Import                              277839     164273       990181
# Globe                                              0          0       904070
# LINZ Address Import                                0          0       860022
# OSM Translator UA                                  0          0       857795
# FixKarlsruheSchema                                 0          0       824301
# addr2osm                                           0          0       735137
# OsmPipeline                                        0          0       651750
# OsmInEdit                                     106842      47741       639047
# custom upload script written in ruby               0          0       623227
# OsmHydrant                                     42327      16919       606440
# mat's little ruby script                           0          0       591995
# LangToolsOSM                                       0          0       571455
# Organic Maps                                  178015      83944       553660
# Services_OpenStreetMap                            41          0       538755
# Mapzen                                             0          0       528485
# OsmSharp                                           0          0       501542
# OSM Editor UA                                      0          0       415557
# Map builder                                   235241          0       408912
# Osm Go!                                        35478      13652       387031
# Rinux                                              0          0       344369
# Win Osm Editor                                     0          0       326545
# Go Kaart!!                                      4271          0       323206
# naptan2osm                                         0          0       285867
# iD-indoor                                        312          0       282349
#                                                 6757          0       270842
# FixDoubleNodes                                     0          0       269951
# RevertUI                                       17218       7932       267201
# OpenGISData                                        0          0       257667
# FixTypo7                                           0          0       255206
# wheelmap.org                                       0          0       232758
# TrimTags                                           0          0       225935
# PHP                                                0          0       218337
# PeoriaJanitor                                      0          0       195442
# David Nicholson                                    0          0       190054
# MapRoulette                                    22649      10632       186023
# TELCOM IP                                          0          0       181820
# Pic4Review                                      9415       1674       176841
# catatom3dfix                                       0          0       176205
# Osmaxil                                            0          0       167272
# Pushpin                                            0          0       157921
# simple_revert.py                                9508       1276       156560
# RawEdit                                            0          0       154842
# Tagger                                             0          0       146189
# bulkyosm.py                                        0          0       141000
# Zaczero/osm-relatify                           72944      30644       132950
# DataNovaImportScripts                          17389          0       129561
# Columbia County                                    0          0       126632
# MaliMrav-Bot                                  108313       7830       116143
# QGIS OSM                                           0          0       110515
# AND retagger                                       0          0       108633
# HI Streams                                         0          0       106530
# osm-rnd 0.0.2-dev osm_act_Commit()            100961          0       100961
# Gerrit Hendriksen                                  0          0        98300
# International Solar Information Solutions          0          0        97578
# Abakus StrazakOSM uploader                      3591       2194        94464
# Findeschorse007                                    0          0        85700
# https://github.com/Cyrille37/yapafo v2.0       81915          0        81915
# OsmSeaShark-EffacerWays                            0          0        79146
# ADDR                                               0          0        77473
# https://wheelmap.org                           42663      24823        77159
